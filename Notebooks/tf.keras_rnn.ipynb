# %% [markdown]
# #Tutorial: Recurrent network model (LSTM)
#
# In this tutorial we train a long-short term memory (LSTM) recurrent model to predict the next letter in a sequence of letters, where the order of letters presented and historical context is necessary to predict the output.

# %% [markdown]
# #Background - Element state and historical context
#
# In a simple way, LSTM networks have internal contextual state and a collection of 'gates' that regulate how they behave as long-term or short-term memory cells.
#
# The output of the LSTM network is modulated by the state of these gates. This is a very important property, that when we need the prediction of the neural network to depend on the historical context of inputs, rather than only on the very last input.
#
#
# ![LSTM Rollout](http://colah.github.io/posts/2015-08-Understanding-LSTMs/img/LSTM3-chain.png)
#
#
# As a simple example, consider that we want to predict the next number of the following sequence: 6 -> 7 -> 8 -> ?. We would like to have the next output to be 9 (x+1). However, if we provide this sequence: 2 -> 4 -> 8 -> ?, we would like to get 16 (2x).
#
# Although in both cases, the current last input was number 8, the prediction outcome should be different (when we take into account the contextual information of previous values and not only the last one).
#
# [Content borrowed from:  https://medium.com/datathings/the-magic-of-lstm-neural-networks-6775e8b540cd ]
#
# [Image linked from: http://colah.github.io/posts/2015-08-Understanding-LSTMs ]

# %% [markdown]
# #Step 0 - Setup the learning environment
# Set the batch size to something reasonably small (<< number of songs) and use a larger number of epochs given that the process only has eight 'song' sequences to look at.  NB: LSTMs are stateful, however the Keras implementation of LSTMs resets the state of the network after each batch.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers


np.random.seed(2)  # for consistancy

batch_size = 4
epochs = 100

print('Environment is ready!')
#print(tf.VERSION)
print(tf.keras.__version__)
# Out:
# Environment is ready!
# 2.8.0

# %% [markdown]
# #Step 1 - Define and prepare the data
# The task is to learn sequences called 'songs' that can be simply thought of as a progression of parts (say chords) in a song, represented by alphabet characeters.  The letters will actually be encoded as integer alphabet indices to make them compatible with the LSTM model.  The final letter in each song is the training label.
#
# Note the **repeating patterns** and similarities between different 'songs'.  For example, songs with labels M and Q ***only differ in two elements***, which occur at very beginning of their sequences.  N is also very similar to these with only a small temporal offest in the repeating pattern.

# %%
alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
song = [
    ['X', 'X', 'A', 'H', 'F', 'E', 'C', 'E', 'B', 'M'],
    ['Y', 'Y', 'Y', 'A', 'H', 'F', 'E', 'C', 'E', 'N'],
    ['F', 'E', 'F', 'C', 'D', 'E', 'F', 'D', 'B', 'O'],
    ['F', 'F', 'F', 'G', 'H', 'G', 'G', 'F', 'E', 'P'],
    ['C', 'B', 'A', 'H', 'F', 'E', 'C', 'E', 'B', 'Q'],
    ['Z', 'X', 'B', 'A', 'B', 'C', 'D', 'E', 'F', 'R'],
    ['W', 'F', 'G', 'H', 'H', 'H', 'G', 'F', 'E', 'L'],
    ['W', 'X', 'Y', 'Z', 'D', 'E', 'F', 'G', 'H', 'K']]

# Translate songs into alphabet indices, put into 'data'
data = []
for row in song:
    # Get the alphabet index for each element the row 
    data.append([alphabet.find(el) for el in row])
data = np.array(data)

# Assume last column as labels and one-hot encode these
labels = data[:, -1]
labels = tf.keras.utils.to_categorical(labels, 26)

# Trim the labels (final column) from the data 
songs = data[:, :-1]

print(songs)

# Reshape into the form [samples(8), time steps(9), features(1)]
songs = np.reshape(songs, [songs.shape[0], songs.shape[1], 1])
# Out:
# [[23 23  0  7  5  4  2  4  1]
#  [24 24 24  0  7  5  4  2  4]
#  [ 5  4  5  2  3  4  5  3  1]
#  [ 5  5  5  6  7  6  6  5  4]
#  [ 2  1  0  7  5  4  2  4  1]
#  [25 23  1  0  1  2  3  4  5]
#  [22  5  6  7  7  7  6  5  4]
#  [22 23 24 25  3  4  5  6  7]]

# %% [markdown]
# #Step 2 - Define model architecture

# %%
model = tf.keras.Sequential()
model.add(layers.LSTM(64, return_sequences=True, input_shape=(songs.shape[1], songs.shape[2])))
model.add(layers.LSTM(32))
model.add(layers.Dense(len(alphabet), activation='softmax'))

# Using stochastic gradient decent with two parameters
sgd = tf.keras.optimizers.SGD(learning_rate=0.1, momentum=0.9)

# Print a quick summary of the model to verify our work
model.summary()

# Compile using some 'typical' parameters for loss, optimizer and error metric
model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 9, 64)             16896
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dense (Dense)               (None, 26)                858
#
# =================================================================
# Total params: 30,170
# Trainable params: 30,170
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Step 3 - Train the model

# %%
model.fit(songs, labels, batch_size, epochs, shuffle=True)
scores = model.evaluate(songs, labels)

print('Accuracy: {0:2.2}'.format(scores[1]))
# Out:
# Epoch 1/100
# 2/2 [==============================] - 3s 12ms/step - loss: 3.1981 - accuracy: 0.0000e+00
# Epoch 2/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.9435 - accuracy: 0.1250
# Epoch 3/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.7020 - accuracy: 0.1250
# Epoch 4/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.5613 - accuracy: 0.1250
# Epoch 5/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.4181 - accuracy: 0.1250
# Epoch 6/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.2575 - accuracy: 0.1250
# Epoch 7/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.1925 - accuracy: 0.1250
# Epoch 8/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1687 - accuracy: 0.3750
# Epoch 9/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.1128 - accuracy: 0.1250
# Epoch 10/100
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0912 - accuracy: 0.1250
# Epoch 11/100
# 2/2 [==============================] - 0s 13ms/step - loss: 2.0071 - accuracy: 0.2500
# Epoch 12/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.8634 - accuracy: 0.2500
# Epoch 13/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.6952 - accuracy: 0.3750
# Epoch 14/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.6171 - accuracy: 0.0000e+00
# Epoch 15/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.6801 - accuracy: 0.2500
# Epoch 16/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.3104 - accuracy: 0.7500
# Epoch 17/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.3581 - accuracy: 0.3750
# Epoch 18/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0067 - accuracy: 0.5000
# Epoch 19/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3029 - accuracy: 0.2500
# Epoch 20/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0087 - accuracy: 0.3750
# Epoch 21/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9320 - accuracy: 0.5000
# Epoch 22/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.3410 - accuracy: 0.3750
# Epoch 23/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.9879 - accuracy: 0.1250
# Epoch 24/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.9297 - accuracy: 0.3750
# Epoch 25/100
# 2/2 [==============================] - 0s 12ms/step - loss: 1.8779 - accuracy: 0.2500
# Epoch 26/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.9372 - accuracy: 0.2500
# Epoch 27/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.7236 - accuracy: 0.3750
# Epoch 28/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.7500 - accuracy: 0.2500
# Epoch 29/100
# 2/2 [==============================] - 0s 16ms/step - loss: 1.6144 - accuracy: 0.2500
# Epoch 30/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.5634 - accuracy: 0.3750
# Epoch 31/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.3490 - accuracy: 0.5000
# Epoch 32/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2632 - accuracy: 0.5000
# Epoch 33/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.1132 - accuracy: 0.7500
# Epoch 34/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.1469 - accuracy: 0.5000
# Epoch 35/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.9427 - accuracy: 0.7500
# Epoch 36/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8169 - accuracy: 0.7500
# Epoch 37/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7229 - accuracy: 0.8750
# Epoch 38/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7287 - accuracy: 0.6250
# Epoch 39/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5764 - accuracy: 0.7500
# Epoch 40/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6084 - accuracy: 0.8750
# Epoch 41/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4711 - accuracy: 0.7500
# Epoch 42/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4567 - accuracy: 0.8750
# Epoch 43/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3683 - accuracy: 0.8750
# Epoch 44/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3681 - accuracy: 0.7500
# Epoch 45/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3003 - accuracy: 0.8750
# Epoch 46/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2653 - accuracy: 0.8750
# Epoch 47/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2968 - accuracy: 0.8750
# Epoch 48/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2476 - accuracy: 0.8750
# Epoch 49/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2193 - accuracy: 0.8750
# Epoch 50/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2287 - accuracy: 0.8750
# Epoch 51/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2538 - accuracy: 0.8750
# Epoch 52/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1983 - accuracy: 0.8750
# Epoch 53/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2067 - accuracy: 0.8750
# Epoch 54/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2014 - accuracy: 0.8750
# Epoch 55/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2228 - accuracy: 0.8750
# Epoch 56/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3924 - accuracy: 0.7500
# Epoch 57/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2169 - accuracy: 0.8750
# Epoch 58/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2807 - accuracy: 0.7500
# Epoch 59/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6045 - accuracy: 0.7500
# Epoch 60/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.8479 - accuracy: 0.5000
# Epoch 61/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4382 - accuracy: 0.6250
# Epoch 62/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7979 - accuracy: 0.6250
# Epoch 63/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4054 - accuracy: 0.7500
# Epoch 64/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5261 - accuracy: 0.7500
# Epoch 65/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3017 - accuracy: 0.8750
# Epoch 66/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3035 - accuracy: 0.8750
# Epoch 67/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6919 - accuracy: 0.6250
# Epoch 68/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2876 - accuracy: 0.8750
# Epoch 69/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4114 - accuracy: 0.7500
# Epoch 70/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4075 - accuracy: 0.7500
# Epoch 71/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3387 - accuracy: 0.8750
# Epoch 72/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2794 - accuracy: 0.7500
# Epoch 73/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2539 - accuracy: 0.8750
# Epoch 74/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2498 - accuracy: 0.8750
# Epoch 75/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2148 - accuracy: 0.8750
# Epoch 76/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2336 - accuracy: 0.7500
# Epoch 77/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2301 - accuracy: 0.8750
# Epoch 78/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2118 - accuracy: 0.8750
# Epoch 79/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2421 - accuracy: 0.7500
# Epoch 80/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2391 - accuracy: 0.8750
# Epoch 81/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2095 - accuracy: 0.8750
# Epoch 82/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2542 - accuracy: 0.8750
# Epoch 83/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2443 - accuracy: 0.8750
# Epoch 84/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2307 - accuracy: 0.7500
# Epoch 85/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1878 - accuracy: 0.8750
# Epoch 86/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1881 - accuracy: 0.8750
# Epoch 87/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1839 - accuracy: 0.8750
# Epoch 88/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1833 - accuracy: 0.8750
# Epoch 89/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2074 - accuracy: 0.7500
# Epoch 90/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1822 - accuracy: 0.8750
# Epoch 91/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1823 - accuracy: 0.8750
# Epoch 92/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1821 - accuracy: 0.8750
# Epoch 93/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2108 - accuracy: 0.7500
# Epoch 94/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2040 - accuracy: 0.8750
# Epoch 95/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2271 - accuracy: 0.7500
# Epoch 96/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2065 - accuracy: 0.8750
# Epoch 97/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1803 - accuracy: 0.8750
# Epoch 98/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1993 - accuracy: 0.8750
# Epoch 99/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1647 - accuracy: 0.8750
# Epoch 100/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2277 - accuracy: 0.8750
# 1/1 [==============================] - 1s 837ms/step - loss: 0.1931 - accuracy: 0.8750
# Accuracy: 0.88

# %% [markdown]
# #Step 4 - Print some sample results

# %%
r = 8

for i in range(r):
    # Choose an individual song at random and format it for testing
    #rand_idx = np.random.randint(0, songs.shape[0])
    test_song  = songs[i] 
    model_input = np.reshape(test_song, [1, 9, 1])
    
    # Given the sequence, predict the next letter
    prediction = model.predict(model_input)
    
    # Decode and print the sequence followed by the predicted next letter
    letter_in = []
    for el in test_song:
        letter_in.append(alphabet[el[0]])
    if np.argmax(prediction) == np.argmax(labels[i]):
        msg='Correct!'
    else:
        msg='Incorrect'
    print("{0} -> {1} ... {2}".format(letter_in, alphabet[np.argmax(prediction)], msg))
# Out:
# ['X', 'X', 'A', 'H', 'F', 'E', 'C', 'E', 'B'] -> M ... Correct!
# ['Y', 'Y', 'Y', 'A', 'H', 'F', 'E', 'C', 'E'] -> N ... Correct!
# ['F', 'E', 'F', 'C', 'D', 'E', 'F', 'D', 'B'] -> O ... Correct!
# ['F', 'F', 'F', 'G', 'H', 'G', 'G', 'F', 'E'] -> P ... Correct!
# ['C', 'B', 'A', 'H', 'F', 'E', 'C', 'E', 'B'] -> Q ... Correct!
# ['Z', 'X', 'B', 'A', 'B', 'C', 'D', 'E', 'F'] -> R ... Correct!
# ['W', 'F', 'G', 'H', 'H', 'H', 'G', 'F', 'E'] -> P ... Incorrect
# ['W', 'X', 'Y', 'Z', 'D', 'E', 'F', 'G', 'H'] -> K ... Correct!

# %% [markdown]
# #Step 5 - Testing for robustness / generalization
# Using testsong, with slight changes to the elements of the input sequences, how does the LSTM perform?
#
# Consider the following changes:
# ![testsong_image](https://aida.acadiau.ca/tl_files/sites/aida/test_song.png)
#
# [testsong](https://drive.google.com/open?id=1rGsyA34QAdQYF8a8rHMtjafM6AKxdGrs)

# %%
testsong = [
    ['X', 'X', 'A', 'H', 'G', 'E', 'C', 'E', 'B', 'M'],
    ['Y', 'Y', 'Y', 'B', 'H', 'F', 'F', 'C', 'E', 'N'],
    ['F', 'E', 'F', 'C', 'D', 'E', 'F', 'D', 'B', 'O'],
    ['F', 'F', 'F', 'G', 'G', 'G', 'G', 'F', 'O', 'P'],
    ['C', 'B', 'A', 'H', 'F', 'E', 'D', 'E', 'B', 'Q'],
    ['Z', 'X', 'B', 'A', 'B', 'E', 'E', 'E', 'F', 'R'],
    ['W', 'F', 'G', 'H', 'H', 'H', 'H', 'F', 'E', 'L'],
    ['W', 'X', 'Y', 'Z', 'D', 'E', 'F', 'G', 'G', 'K']]

# In practice, we would never rewrite a section of code like this!

testdata = []
for row in testsong:
    # Get the alphabet index for each element the row 
    testdata.append([alphabet.find(el) for el in row])
testdata = np.array(testdata)
testlabels = testdata[:, -1]
testlabels = tf.keras.utils.to_categorical(testlabels, 26)
testsongs = testdata[:, :-1]
testsongs = np.reshape(testsongs, [testsongs.shape[0], testsongs.shape[1], 1])

r = 8
for i in range(r):
    test_song  = testsongs[i] 
    model_input = np.reshape(test_song, [1, 9, 1])
    prediction = model.predict(model_input)
    letter_in = []
    for el in test_song:
        letter_in.append(alphabet[el[0]]) 
    if np.argmax(prediction) == np.argmax(testlabels[i]):
        msg='Correct!'
    else:
        msg='Incorrect'
    print("{0} -> {1} ... {2}".format(letter_in, alphabet[np.argmax(prediction)], msg))
# Out:
# ['X', 'X', 'A', 'H', 'G', 'E', 'C', 'E', 'B'] -> M ... Correct!
# ['Y', 'Y', 'Y', 'B', 'H', 'F', 'F', 'C', 'E'] -> N ... Correct!
# ['F', 'E', 'F', 'C', 'D', 'E', 'F', 'D', 'B'] -> O ... Correct!
# ['F', 'F', 'F', 'G', 'G', 'G', 'G', 'F', 'O'] -> P ... Correct!
# ['C', 'B', 'A', 'H', 'F', 'E', 'D', 'E', 'B'] -> Q ... Correct!
# ['Z', 'X', 'B', 'A', 'B', 'E', 'E', 'E', 'F'] -> R ... Correct!
# ['W', 'F', 'G', 'H', 'H', 'H', 'H', 'F', 'E'] -> P ... Incorrect
# ['W', 'X', 'Y', 'Z', 'D', 'E', 'F', 'G', 'G'] -> K ... Correct!
